# %%
import re
import requests
home_page =requests.get('https://energy.economictimes.indiatimes.com/').text
main_page = re.search('<a\s*id=\'home\'(.*?)<li\s*class="more hide">',home_page,re.S).group(1)
print(main_page)
# # url = re.findall('href="(.*?)"',home_page)
# for i in main_page.split('href="https://energy.econ\smictimes')[1:]:
#     print(i)
# Out:
#  aria-label='Home' href='https://energy.economictimes.indiatimes.com' data-modname="Header" aria-label='&lt;i class='fa fa-home'&gt;&lt;/i&gt;'><i class='fa fa-home'></i></a></li><li class='dropdown '><a id="news" href="javascript:void(0);"  data-modname="Header" aria-label="News" >News <i class="fa fa-angle-down mob-hide"></i></a><div class="dropdown-item newsDropdownhvr mob-hide"><div class="tabbedcontent v-nav-wrapper"><div id="v-nav" class="prev-nav-list"><ul><li><a href="https://energy.economictimes.indiatimes.com/news/oil-and-gas" data-modname="Header"  aria-label="Oil &amp; Gas" >Oil & Gas</a></li><li><a href="https://energy.economictimes.indiatimes.com/news/coal" data-modname="Header"  aria-label="Coal" >Coal</a></li><li><a href="https://energy.economictimes.indiatimes.com/news/power" data-modname="Header"  aria-label="Power" >Power</a></li><li><a href="https://energy.economictimes.indiatimes.com/news/renewable" data-modname="Header"  aria-label="Renewable" >Renewable</a></li
# ...

# %%
# Out:
# https://st.etb2bimg.com/Themes/Release/images/site-logos/etfavicon-energy-2.ico
# https://st.etb2bimg.com/Themes/Release/images/responsive/etenergyworld-logo-400x400.jpg
# https://energy.economictimes.indiatimes.com
# https://energy.economictimes.indiatimes.com
# https://js.etb2bimg.com
# https://etimg.etb2bimg.com
# https://img.etb2bimg.com
# https://st.etb2bimg.com
# //www.google-analytics.com
# //tpc.googlesyndication.com
# //apis.google.com
# //connect.facebook.net
# //cm.g.doubleclick.net
# //googleads.g.doubleclick.net
# //googleads.g.doubleclick.net
# https://etimg.etb2bimg.com
# https://img.etb2bimg.com
# https://st.etb2bimg.com
# https://js.etb2bimg.com
# https://energy.economictimes.indiatimes.com
# //b.scorecardresearch.com
# //www.google-analytics.com
# //tpc.googlesyndication.com
# //apis.google.com
# //connect.facebook.net
# //cm.g.doubleclick.net
# //googleads.g.doubleclick.net
# https://etimg.etb2bimg.com
# https://img.etb2bimg.com
# https://st.etb2bimg.com
# ...

# %%
# Out:
# <!DOCTYPE html>
# <html lang="en" itemscope itemtype="http://schema.org/WebPage" >
#
# <head>
#     <title>
#     Energy News | Latest Energy Industry Information and Updates: ET EnergyWorld</title>
#
#
#
#     <meta itemprop="name" content="Energy News | Latest Energy Industry Information and Updates: ET EnergyWorld" />
#         <meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# ...
