# %%
#http://businesstimes.com.sg

# %%
import json
import os 
import requests
import time
from datetime import datetime,timedelta
from datetime import date
import re
import sys
import urllib, urllib.request, urllib.parse
import random
from scrawl import *
    
# Date and time
start_time = time.time()
current_time = datetime.now().strftime("%H-%M-%S")
created_on = date.today().strftime("%Y-%m-%d")

# client_id = sys.argv[1]
client_id = '5f69d22ef472d6646f577fa6'  # Europe
site = 'businesstimes_com_sg'
c = Crawl()  # creating object

# create directories to store logs.
log_path = c.create_directories(project_path, client_id, site)

# create image directories
image_directory = c.create_image_directories(project_path)

# logger
logger = log_func(log_path, created_on, current_time)
logger.info("Process Started ...\n")

# initialize variables
skipped_due_to_headline = 0
skipped_due_to_content = 0
skipped_due_to_date = 0
missing_overall_tonality = 0
no_of_data = 0
duplicate_data = 0  
unable_to_fetch_article_url = 0
unable_to_fetch_cat_url = 0
publish_source = 'businesstimes.com.sg'
country = 'Singapore'
language = 'English'
images_path = []
cookies = {
    'XywkqJyC': 'AEybcm14AQAAhDupNHa18aOes4nu8JcBdze6C46z2fW9xKhnZNvqK4izCpV6|1|1|496e119641b20ed189a9f600d5e3292e8bd37c75',
    'juLD4H3B': 'AEybcm14AQAAyYYeyQkHJTSU6pcu04tpyn9OtbCp-SX_kyLVUNvqK4izCpV6',
    'has_js': '1',
    'topoverlayDisplayed': 'yes',
    'topOverlayImpressionsServed': '0',
    'NSC_JOlo3vprczwsrc0em1nifnbukr3oebt': 'ffffffff09a3792945525d5f4f58455e445a4a423660',
    '_ga': 'GA1.3.429338857.1616743939',
    '_gid': 'GA1.3.42625048.1616743939',
    '_fbp': 'fb.2.1616743940045.1623211001',
    '_hjTLDTest': '1',
    '_hjid': '62234f58-60b4-4798-9c33-90d464a14e32',
    '_hjFirstSeen': '1',
    'optimizelyEndUserId': 'oeu1616743940888r0.7228898367865182',
    '_cb_ls': '1',
    '_cb': 'DIt1_8DEtYWoCaF7Ow',
    '_chartbeat2': '.1616743943907.1616743943907.1.kIHeID480nsP4xNJBnLgCngHwZ3.1',
    '_cb_svref': 'null',
    '_ga_M8PMESFDLF': 'GS1.1.1616743944.1.0.1616743944.60',
    '_ncid': '806433bfb1bf32f62baf46a1975f408a',
    '_cc_id': '7ad54f32f5abdebbab1085542f4ec3e7',
    '_cc_cc': 'ACZ4nGNQME9MMTVJMzZKM01MSklNSkpMMjSwMDU1MUozSU02TjVnAIKE2D42Bjjg7bm8i53xmyLDf0ZGhuV%2FCmHMc0cPMcPY579Ywpi7910WgLEPL57DAmPfXPuUG8bu2jQFLn79vDqMeenUIzYY%2B90ShNYPDffhRh57OgmuHgAerEK2',
    '_cc_aud': 'ABR4nGNgYGBIiO1jY4ABZgaGk%2F0gButSDbDAyXYgAQBVqATP',
    'X-AMAGENT-TX': 'XjYvoXy/kRtH1rqbqFSjSPFRWbOeZrEyrF6YYkxvnYkLsVR/dvjkLLjpMfvBykzBQfl7wXQzN9QFiCGKfby9VSwrm5y1yn/qeWkHFSLvyP35ls8/QiwlsCl5X06aHmRPjhQtXs5NfPi9ZlF1XbFLUh9RAHz9pdpCQmlfnwi0LbhyL58AKsEbg9R4+NC0BnlsIZDDAuG3B5Mur/1xwQb3bw==',
    '_hjIncludedInPageviewSample': '1',
    '_hjAbsoluteSessionInProgress': '1',
    'suid': '31af00bece494193890519164a414d7a',
    'sessionStatus': '1',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:86.0) Gecko/20100101 Firefox/86.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'If-Modified-Since': 'Fri, 26 Mar 2021 07:31:41 GMT',
    'Cache-Control': 'max-age=0',
    'TE': 'Trailers',
}

home_page= requests.get('https://www.businesstimes.com.sg/', headers=headers, cookies=cookies, timeout=120).text

home_page = c.scrap('<ul\s*class="list-group">(.*?)<div\s*class="col-md-4\s*visible-md\s*visible-lg">', home_page)
# print(home_page)
# abc
# # print(rss_pages)
for _ in home_page.split('<a href=')[1:-3]: #-3   # -1 is used to exclude the last element of list
    
    cat_url = c.scrap('"(.*?)"', _)   #c.scrap is a re.search()
    if 'http' not in cat_url:
        cat_url = 'https://www.businesstimes.com.sg' +  cat_url
#     print(cat_url)
#     continue
    logger.info(f'Fetching cat url  {cat_url}\n')
    cat_page = requests.get(cat_url, headers=headers, cookies=cookies, timeout=120).text
    
    if cat_page.startswith('Unable to fetch'):
        logger.info(cat_page) # writes error message with error code
        unable_to_fetch_cat_url += 1
        continue    
    if 'class="col-lg-12' in cat_page:  # cat_page mai pura page download hoga,so uspage  mai check karenyag
        cat_pages=c.scrap('<div\s*class="col-lg-12(.*?)"pager\s*pager-show-more"', cat_page)
    else:
         cat_pages=c.scrap('<div\s*class="col-lg-8(.*?)"pager\s*pager-show-more"', cat_page)
    for i in cat_pages.split('<h2 class="widget__title">')[1:]:##<div class="widget__meta">

        # source_link
        source_link = c.scrap('<a\s*href="(.*?)"', i)
        
        if 'http' not in source_link:
            source_link = 'https://www.businesstimes.com.sg' +  source_link
#         print(source_link)
#         continue
        # handle duplicates
        source_link_query = {'source_link':source_link}
        dic = cl_data.find_one(source_link_query,{'source_link': 1}) 
        if dic:
            duplicate_data += 1
            continue

        time.sleep(random.randint(1,3))

        logger.info(f'Fetching {source_link}\n')
        
        page = requests.get(source_link, headers=headers, cookies=cookies, timeout=120).text   # here the page wil get download
        
        if page.startswith('Unable to fetch'):     
            logger.info(page) # writes error message with error code
            unable_to_fetch_article_url += 1
            continue    

        source_headline = c.scrap('<title>(.*?)</title>', page)#<meta property="og:title" content="
        
        # skip if headline not found
        if not source_headline:
            logger.info(f'Skipping due to headline {source_link}\n')
            skipped_due_to_headline += 1
            continue
            
         # Date and time
        pub_date, publish_time = '', ''

        try:
        #"datePublished": "2021-03-26T05:50:00+08:00",
            date_time_str = c.scrap('"datePublished":(.*?)\+', page) 
            if not date_time_str:              
                date_time_str = c.scrap('published_time.*?content="(.*?)\+', page)  
            date_time_str = re.sub('[^\w+]', '', date_time_str)  # to subsitute everything which is not digite
    #         print(date_time_str)
            date_time_obj = datetime.strptime(date_time_str, '%Y%m%dT%H%M%S')
#             print(date_time_str)
#             continue
            ist_date_time = date_time_obj - timedelta(hours = 2,minutes = 30)  
            ist_date_time = ist_date_time.strftime('%Y-%m-%d %H:%M:%S')
            pub_date = ist_date_time[:10]
            publish_time = ist_date_time[11:]
            
        except:
            pass
        
        # skip null date
        if not pub_date:
            logger.info(f'Skipping due to date {source_link}\n')            
            skipped_due_to_date += 1
            continue

        # break if date is not today's date
        if pub_date != created_on:
            break    

        
#         h2 = c.scrap('name="description"\s*content="(.*?)'

        # source_content          div class="body-copy">                  #<div class="field field-name-body
        source_content= c.scrap('div\s*class="field\s*field-name-body.*?>(.*?)<section\s*id=',page)    
        if not source_content:
            source_content= c.scrap('<div\s*class="field-body">(.*?)<section\s*id=',page)
        source_content = c.strip_html(source_content)
        if not source_content:
            logger.info(f'Skipping due to content {source_link}\n')            
            skipped_due_to_content += 1
            continue

        
        journalist =c.scrap("'author-name':'(.*?)'",page)

        if not journalist: journalist = 'NA'

        # current date and time 00
        harvest_time = datetime.now().strftime("%H:%M:%S")

        # temp link
        temp_link = source_link

        # headline and content 
        headline = source_headline
        content = source_content

        # overall_tonality
        overall_tonality = ''

        # word count
        word_count = len((source_headline + ' ' + source_content).split())

        html_content = ''

        # image_urls
        image_urls = []
        
#         print('source_link', source_link, '\n')
#         print('source_headline', source_headline,'\n')
#         print('pub_date', pub_date,'\n')
#         print('publish_time', publish_time,'\n')
#         print('journalist', journalist,'\n')
#         print('source_content', source_content,'\n')
#         print('html_content', html_content, '\n')
#         print('image_urls', image_urls, '\n')

    

        # storing the above data in a dictionary
        clientdata ={
                        "client_master" : client_id, 
                        "articleid":client_id,
                        "medium":'Web' ,
                        "searchkeyword":[],
                        "entityname" : [] ,
                        "process_flage":"1",
                        "na_flage":"0",
                        "na_reason":"",
                        "qc_by":"",
                        "qc_on":"",
                        "location":"",
                        "spokeperson":"",
                        "quota":"",
                        "overall_topics":"",
                        "person":"",
                        "overall_entites":"",
                        "overall_tonality": overall_tonality,
                        "overall_wordcount":word_count,
                        "article_subjectivity":"",
                        "article_summary":"",
                        "pub_date":pub_date,
                        "publish_time":publish_time,
                        "harvest_time":harvest_time,
                        "temp_link":temp_link,
                        "publish_source": publish_source,
                        "programme":'null',
                        "feed_class":"News",
                        "publishing_platform":"",
                        "klout_score":"",
                        "journalist":journalist,
                        "headline":headline,
                        "content":content,
                        "source_headline":source_headline,
                        "source_content":source_content,
                        "language":language,
                        "presence":'null',
                        "clip_type":'null',
                        "prog_slot":'null',
                        "op_ed":'0',
                        "location_mention":'',
                        "source_link":source_link,
                        "author_contact":'',
                        "author_emailid":'',
                        "author_url":'',
                        "city":'',
                        "state":'',
                        "country":country,
                        "source":publish_source,
                        "foot_fall":'',
                        "created_on":created_on,
                        "active":'1',
                        'crawl_flag':2,
                        "images_path":images_path,
                        "html_content":html_content
                    } 

        cl_data.insert_one(clientdata)  
        no_of_data += 1


logger.info('Iteration complete\n')   

logger.info(f'Number of data: {no_of_data}\n')
logger.info(f'Duplicate data: {duplicate_data}\n')
logger.info(f'Unable to fetch cat url: {unable_to_fetch_cat_url}\n')
logger.info(f'Unable to fetch article url: {unable_to_fetch_article_url}\n')
logger.info(f'Skipped due to headline: {skipped_due_to_headline}\n')
logger.info(f'Skipped due to content: {skipped_due_to_content}\n')
logger.info(f'Skipped due to date: {skipped_due_to_date}\n')
logger.info(f'Processing finished in {time.time() - start_time} seconds.\n')

# %%
# Out:
# {}
# {}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-da2230580b32> in <module>
#      11 }
#      12 a_session = requests.Session()
# ---> 13 response = session.get('https://www.businesstimes.com.sg/')
#      14 # a_session.get('https://www.businesstimes.com.sg/')
#      15 # session_cookies = a_session.cookies
#
# NameError: name 'session' is not defined

# %%
import requests

cookies = {
    'XywkqJyC': 'AEybcm14AQAAhDupNHa18aOes4nu8JcBdze6C46z2fW9xKhnZNvqK4izCpV6|1|1|496e119641b20ed189a9f600d5e3292e8bd37c75',
    'juLD4H3B': 'ADOSDRd5AQAAeZX7GODHB3iQf-mmVynRo56t-MUNoRM78Yikf4F1wsx_M8_-',
    '_ga': 'GA1.3.429338857.1616743939',
    '_fbp': 'fb.2.1616743940045.1623211001',
    '_hjid': '62234f58-60b4-4798-9c33-90d464a14e32',
    'optimizelyEndUserId': 'oeu1616743940888r0.7228898367865182',
    '_cb_ls': '1',
    '_cb': 'DIt1_8DEtYWoCaF7Ow',
    '_chartbeat2': '.1616743943907.1619589443402.0000000000000001.BY71_oB83Ynv0u_gKC13KvgD_xAXb.1',
    '_ga_M8PMESFDLF': 'GS1.1.1619589443.3.0.1619589443.60',
    '_ncid': '806433bfb1bf32f62baf46a1975f408a',
    '_cc_id': '7ad54f32f5abdebbab1085542f4ec3e7',
    '_cc_cc': 'ACZ4XmNQME9MMTVJMzZKM01MSklNSkpMMjSwMDU1MUozSU02TjVnAIKEjp%2FOh1de%2BscP4oCByMwnD9kZvynu7%2F37n%2F8%2FIyPD1us9XMj81Wj8VWj8lWj8nsu7QOYxgMxa%2FqcQyDwIM7pr0xQWZP65o4eYkfmXTj1iQ%2Bbv3ndZAJn%2FoeE%2BCv%2Fw4jko5t1c%2B5QbWf27Jajy579YIktfP6%2BOzD32dBIK%2F9mHX5pAebBHnkFsArMBn1ieVw%3D%3D',
    '_cc_aud': 'ABR4XmNgYGBI6PjpDKQggJmB4WQ%2FiMm6VAMscrIdSAAAcMkFog%3D%3D',
    'suid': '31af00bece494193890519164a414d7a',
    '__gads': 'ID=fa51c528a3ff4d00-2283dda7dac60000:T=1616744076:S=ALNI_Mby3aD268CVfJGmf7eOW7fAWS_Ccw',
    'has_js': '1',
    'topOverlayImpressionsServed': '1',
    'NSC_JOlo3vprczwsrc0em1nifnbukr3oebt': 'ffffffff09a3792945525d5f4f58455e445a4a423660',
    '_gid': 'GA1.3.1071411636.1619589427',
    'outbrain_cid_fetch': 'true',
    'UserFirstVisit': '1',
    'X-AMAGENT-TX': 'chUW89Z2Rz9j6tBnWdZzUzkaLUfdkaohRVxvw+6mKmf9PXP6QQx/uZN7yuZgEnotsuf2PZFdI13XiTcsec1rsUyGU8/7hVJlBFvLt97Mh4w3ubkWQLA/TAM+yVxtHnGQi05DKc1IzHTddv6VsT7OpUmIAZqO/g+Rn4ebieCI628zd8IH7jgpwIsFj3IHQ1wN/0uDdtvkk1KIbPXnGh9vfA==',
    '_dc_gtm_UA-21603044-1': '1',
    '_cb_svref': 'null',
    '_hjIncludedInPageviewSample': '1',
    '_hjTLDTest': '1',
    '_hjAbsoluteSessionInProgress': '0',
    '_gat_UA-21603044-1': '1',
    'sessionStatus': '1',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'If-Modified-Since': 'Wed, 28 Apr 2021 05:57:11 GMT',
    'Cache-Control': 'max-age=0',
    'TE': 'Trailers',
}

response = requests.get('https://www.businesstimes.com.sg/', headers=headers, cookies=cookies)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 8]><html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en" dir="ltr"  prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# schema: http://schema.org/">
# <!--<![endif]-->
#
# <head profile="http://www.w3.org/1999/xhtml/vocab">
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge"><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"5d870fc25a",applicationID:"439190759"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:this,n),t?void 0:this}}var o=e("handle"),a=e(7),c=e(8),f=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(e,t){s[t]=i(p+t,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),t.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,t){var n={},r=this,i="function"==typeof t;return o(l+"tracer",[u.now(),e,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return t.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],n),e}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,t){m[t]=i(l+t)}),newrelic.noticeError=function(e,t){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,t])}},{}],2:[function(e,t,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=e(9);t.exports=r,t.exports.offset=a,t.exports.getLastTimestamp=i},{}],3:[function(e,t,n){function r(e){return!(!e||!e.protocol||"file:"===e.protocol)}t.exports=r},{}],4:[function(e,t,n){function r(e,t){var n=e.getEntries();n.forEach(function(e){"first-paint"===e.name?d("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&d("timing",["fcp",Math.floor(e.startTime)])})}function i(e,t){var n=e.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(e){e.getEntries().forEach(function(e){e.hadRecentInput||d("cls",[e])})}function a(e){if(e instanceof m&&!g){var t=Math.round(e.timeStamp),n={type:e.type};t<=p.now()?n.fid=p.now()-t:t>p.offset&&t<=Date.now()?(t-=p.offset,n.fid=p.now()-t):t=p.now(),g=!0,d("timing",["fi",t,n])}}function c(e){d("pageHide",[p.now(),e])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var f,u,s,d=e("handle"),p=e("loader"),l=e(6),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){f=new PerformanceObserver(r);try{f.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,w=["click","keydown","mousedown","pointerdown","touchstart"];w.forEach(function(e){document.addEventListener(e,a,!1)})}l(c)}},{}],5:[function(e,t,n){function r(e,t){if(!i)return!1;if(e!==i)return!1;if(!t)return!0;if(!o)return!1;for(var n=o.split("."),r=t.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var c=navigator.userAgent,f=c.match(a);f&&c.indexOf("Chrome")===-1&&c.indexOf("Chromium")===-1&&(i="Safari",o=f[1])}t.exports={agent:i,version:o,match:r}},{}],6:[function(e,t,n){function r(e){function t(){e(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&document.addEventListener(o,t,!1)}t.exports=r;var i,o,a;"undefined"!=typeof document.hidden?(i="hidden",o="visibilitychange",a="visibilitySt ...
#   <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
#   <meta property="fb:admins" content="100008016031098" />
#   <meta name="google-site-verification" content="64YzaSIKUvOcgG1DccSNNzlWDqXwjSx4lDDgbgtDLJE" />
#   <!--[if IE]><![endif]-->
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <link rel="image_src" href="https://www.businesstimes.com.sg/sites/all/themes/custom/businesstimes/images/BTdefault800.png" />
# <meta name="articleid" content="348051" />
# <meta property="al:ios:url" content="businesstimes://www.businesstimes.com.sg/" />
# <meta property="al:ios:app_store_id" content="531275824" />
# <meta property="al:ios:app_name" content="BusinessTimes" />
# <meta property="al:android:url" content="https://www.businesstimes.com.sg/" />
# <meta property="al:android:package" content="com.ps.bt" />
# <meta property="al:android:app_name" content="The Business Times" />
# <meta property="al:web:url" content="https://www.businesstimes.com.sg/" />
# <meta name="article:pageclass" content="frontpage" />
# <link rel="shortcut icon" href="https://www.businesstimes.com.sg/sites/default/files/favicon-5.png" type="image/png" />
# <meta name="description" content="THE BUSINESS TIMES - Find latest business &amp; financial news including analysis and opinion on top business stories, stock markets in Singapore, Asia-Pacific &amp; global market news and more at The Business Times." />
# <meta name="keywords" content="singapore budget 2015, singapore, budget 2015, business &amp; financial news" />
# <meta property="created" content="1619560200" />
# <meta property="updated" content="1619588331" />
# <link rel="canonical" href="https://www.businesstimes.com.sg/" />
# <meta property="fb:pages" content="288031731262011" />
# <link rel="shortlink" href="https://www.businesstimes.com.sg/" />
# <meta property="fb:app_id" content="328386607332790" />
# <meta property="og:site_name" content="The Business Times" />
# <meta property="og:type" content="website" />
# <meta property="og:url" content="https://www.businesstimes.com.sg/" />
# <meta property="og:title" content="The Business Times" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="@BusinessTimes" />
# <meta name="twitter:url" content="https://www.businesstimes.com.sg/" />
# <meta name="twitter:title" content="The Business Times" />
# <meta name="twitter:app:country" content="US" />
# <meta name="twitter:app:id:iphone" content="531275824" />
# <meta name="twitter:app:url:iphone" content="com.sph.bt://url=https://www.businesstimes.com.sg/home" />
# <meta name="twitter:app:id:ipad" content="531283825" />
# <meta name="twitter:app:url:ipad" content="com.sph.bt://url=https://www.businesstimes.com.sg/home" />
# <meta name="twitter:app:id:googleplay" content="com.ps.bt" />
# <meta name="twitter:app:url:googleplay" content="com.sph.bt://url=https://www.businesstimes.com.sg/home" />
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window,document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#
#   fbq('init', '3658941557531461');
#   fbq('track', 'PageView');
# </script>
# <noscript>
#   <img height="1" width="1"
#   src="https://www.facebook.com/tr?id=3658941557531461&ev=PageView
#   &noscript=1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
#   <title>THE BUSINESS TIMES - Get the Latest Business & Financial News</title>
#
#   <!-- Mobile icons for iOS 7 or prior (legacy) -->
#   <link rel="apple-touch-icon" sizes="144x144" href="/icons/bt-apple-touch-icon-144x144.png">
#   <link rel="apple-touch-icon" sizes="114x114" href="/icons/bt-apple-touch-icon-114x114.png">
#   <link rel="apple-touch-icon" sizes="72x72" href="/icons/bt-apple-touch-icon-72x72.png">
#   <link rel="apple-touch-icon" sizes="57x57" href="/icons/bt-apple-touch-icon-57x57.png">
#
#   <!-- Mobile icons for iOS 8 and later -->
#   <link rel="apple-touch-icon" sizes="180x180" href="/icons/bt-apple-touch-icon-180x180.png">
#   <link rel="apple-touch-icon" sizes="152x152" href="/icons/bt-apple-touch-icon-152x152.png">
#   <link rel="apple-touch-icon" sizes="120x120" href="/icons/bt-apple-touch-icon-120x120.png">
#   <link rel="apple-touch-icon" sizes="76x76" href="/icons/bt-apple-touch-icon-76x76.png">
#   <link rel="apple-touch-icon" sizes="60x60" href="/icons/bt-apple-touch-icon-60x60.png">
#
#   <link type="text/css" rel="stylesheet" href="/sites/default/files/advagg_css/css__9cWqptSUNYq5YedfIwh33VxtugFVWjDdEsblT8GhLKI__quUjyhSfbEukHj8a0hYvzm9VTmPALmSZvA0xfM_Oxzo__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.css" media="all" />
# <link type="text/css" rel="stylesheet" href="/sites/default/files/advagg_css/css__swTCPtX0016u9yQSamgZkZDfvCbL0cyhAvFGljdNLeA__W3xqIT_nfIK8iJ32vUyEHw0i6fhhMti1u6TzTwQ_zuk__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.css" media="all" />
# <link type="text/css" rel="stylesheet" href="/sites/default/files/advagg_css/css__LdsBalUdGQgPuLAhJeaO1gjqQBMJ0tbCOvfPEZSkXWo__Qjk0IqDb9nVeCEVzqvi6cMhwAjp1rq9Z6JZZuX50eQI__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.css" media="all" />
# <link type="text/css" rel="stylesheet" href="/sites/default/files/advagg_css/css__YJPlRDiwDsRz0-pOtt8tuKijHd6n0NWrkxlhGSf3h8A__gA-4wU4TUrmttp3Gf2mg7CSUv04fff34maZXL4AD6Xo__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.css" media="all" />
# <link type="text/css" rel="stylesheet" href="/sites/all/libraries/lightslider/css/lightslider.css?v2&amp;qs7qoq" media="all" />
# <link type="text/css" rel="stylesheet" href="/sites/default/files/advagg_css/css__7dbnB1CcwSqw08q6q2LaZ0KPTDZCuLjJ3MepLbYSqQc__PgyaAsp3_P74BEE2wFHC9j3AcwtqsOu6q-H7rvQLNMc__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.css" media="all" />
#   <link
#     href='https://fonts.googleapis.com/css?family=Poppins:300,600|Raleway:700|Open+Sans:300,400,600,700,700i,400i,300i|Lato:400,700|Playfair+Display:400,700,700italic,400italic|PT+Sans:400,400i,700,700i|PT+Serif:400,400i,700,700i|Heebo:500,700'
#     rel='stylesheet' type='text/css'>
#   <!-- HTML5 element support for IE6-8 //-->
#   <!--[if lte IE 8]>
#     <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#     <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#   <![endif]-->
#
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
#     integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" crossorigin="anonymous">
#   </script>
#
#   <!-- Google Optimize  -->
#   <style>
#   .async-hide {
#     opacity: 0 !important
#   }
#   </style>
#   <script>
#   (function(a, s, y, n, c, h, i, d, e) {
#     s.className += ' ' + y;
#     h.start = 1 * new Date;
#     h.end = i = function() {
#       s.className = s.className.replace(RegExp(' ?' + y), '')
#     };
#     (a[n] = a[n] || []).hide = h;
#     setTimeout(function() {
#       i();
#       h.end = null
#     }, c);
#     h.timeout = c;
#   })(window, document.documentElement, 'async-hide', 'dataLayer', 4000, {
#     'GTM-TD3P2LC': true
#   });
#   </script>
#
#   <!-- [start] asean/garage widget -->
#   <script>
#   window.showAseanGarage = true;
#   if (document.cookie.indexOf("topoverlayDisplayed=") == -1) {
#     window.showAseanGarage = false;
#   }
#   </script>
#   <!-- [end] asean/garage widget -->
#
#   <!-- Modified Analytics tracking code with Optimize plugin -->
#   <script>
#   (function(i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function() {
#       (i[r].q = i[r].q || []).push(arguments)
#     }, i[r].l = 1 * new Date();
#     a = s.createElement(o),
#       m = s.getElementsByTagName(o)[0];
#     a.async = 1;
#     a.src = g;
#     m.parentNode.insertBefore(a, m)
#   })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#   ga('create', 'UA-21603044-1', 'auto');
#   ga('require', 'GTM-TD3P2LC');
#   </script>
#   <!-- End Google Optimize -->
#
#   <!-- Google Tag Manager -->
#   <script>
#   (function(w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({
#       'gtm.start': new Date().getTime(),
#       event: 'gtm.js'
#     });
#     var f = d.getElementsByTagName(s)[0],
#       j = d.createElement(s),
#       dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src =
#       'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
#   })(window, document, 'script', 'dataLayer', 'GTM-WH9XNQW');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- [start] PRE-BID TAGS -->
#     <script>
#   var homepage = 1;
#   </script>
#
#   <!-- For ads -->
#   <script type="text/javascript">
#   var show_overlay = 0;
#   /** Get cookie by name */
#   window.getCookieByName = function(name) {
#     match = document.cookie.match(new RegExp(name + '=([^;]+)'));
#     if (match) return match[1];
#   }
#
#   var overlay_validity = 4;
#   var catfish_validity = 4;
#   var postitial_validity = 4;
#   var topOverlayImpressions = 3;
#   var topOverlayImpressionsServed = 0;
#
#   if (window.getCookieByName("topOverlayImpressionsServed") != undefined) {
#     var topOverlayImpressionsServed = parseInt(window.getCookieByName("topOverlayImpressionsServed"));
#   }
#
#   if (window.getCookieByName("mySPHUserType") != undefined) {
#     topOverlayImpressionsServed = 2;
#   }
#   </script>
#
#   <!-- START SMX -->
#     <script type="text/javascript">
#   var loaded_dfp_tags = '{"bi1":{"adunit":"\/5908\/bt\/bi1\/homepage","slotname":"dfp-ad-bi1","size":"fluid"},"imu2":{"adunit":"\/5908\/bt\/imu2\/homepage","slotname":"dfp-ad-imu2","size":"300x250"},"imu1":{"adunit":"\/5908\/bt\/imu1\/homepage","slotname":"dfp-ad-imu1","size":"fluid,300x250"},"lb1":{"adunit":"\/5908\/bt\/lb1\/homepage","slotname":"dfp-ad-lb1","size":"970x90,728x90,970x250,320x50,320x100,320x250"},"catfish":{"adunit":"\/5908\/bt\/catfish\/homepage","slotname":"dfp-ad-catfish","size":"1x1"},"prestitial":{"adunit":"\/5908\/bt\/prestitial\/homepage","slotname":"dfp-ad-prestitial","size":"1x1"}}';
#   </script>
#   <!-- END SMX -->
#   <script>
#   var outbrain_enable = 1;
#   </script>
#   <script src="//www.googletagservices.com/tag/js/gpt.js"></script>
#   <script src="//adtag.sphdigital.com/tag/smx/prebid.js"></script>
#   <script src="//adtag.sphdigital.com/tag/smx/smx_prebid.js"></script>
#
#   <!-- [end] PRE-BID TAGS -->
#
#   <!-- QueryDFP preview-->
#   <script type="text/javascript">
#   function querydfp_preview(e) {
#     for (var n, r = new RegExp("(?:\\?|&)" + e + "=(.*?)(?=&|$)", "gi"), c = []; null != (n = r.exec(document.location
#         .search));) c[c.length] = n[1];
#     return c
#   }
#   var dfp_preview_ids = querydfp_preview('dfp_preview');
#   </script>
#   <!-- QueryDFP preview -->
#
#   <!-- Get referrer -->
#   <script type="text/javascript">
#   function getreferrer() {
#     var e = "direct",
#       r = "";
#     return document.referrer.split("/")[2] && (r = document.referrer.split("/")[2], e = /google/i.test(r) ? "google" :
#       /facebook/i.test(r) ? "facebook" : "others"), e
#   }
#   var tarref = getreferrer();
#   </script>
#   <!-- Get referrer -->
#
#   <script type="text/javascript" src="/sites/default/files/advagg_js/js__8c_EPWbFb6mspxIs2B3rW40hmuSM_PDqlaeGNbhqaoc__cF4r9ykoSmuvBlskdYkpwHuXe0yTMIPBYdr_U9eoDaY__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];/** Get cookie by name */
# window.getCookieByName = function (name) {
#   match = document.cookie.match(new RegExp(name + '=([^;]+)'));
#   if (match) return match[1];
# }
#
# if (window.getCookieByName("mySPHUserType") != undefined && window.getCookieByName("mySPHUserType") == "sub") {
#   topOverlayImpressionsServed = topOverlayImpressions - 1;
# }
# googletag.slots = googletag.slots || {};
# //--><!]]>
# </script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__9ici6QMeDS-cROq8R0RhuICsMGMP2wcJZNQQFsqQi44__kScSwG4RXGl1LXnj4qqt0ZxtNX4Gh2TK5W-o8Uup4SA__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__uH9U9My11aIDY4c0fh8zMkTlvjsONNugeyb7EsmYwow__2-hXUuJFFVI9lB3-7rDOKJh4TQwGwmFY-5Y3_wu00b4__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# googletag.cmd.push(function() {
# var mapping = googletag.sizeMapping()
#   .addSize([1024, 0], [[970, 90], [728, 90], [970, 250]])
#   .addSize([740, 0], [728, 90])
#   .addSize([320, 0], [[320, 50], [320, 100], [320, 250]])
#   .addSize([0, 0], [[320, 50], [320, 100], [320, 250]])
#   .build();
# googletag.slots["lb1"] = googletag.defineSlot("/5908/bt/lb1/homepage", [[970, 90], [728, 90], [970, 250], [320, 50], [320, 100], [320, 250]], "dfp-ad-lb1")
#   .addService(googletag.pubads())
#   .setTargeting("pos", "1")
#   .setTargeting("weight", "1")
#   .defineSizeMapping(mapping);});
#
# //--><!]]>
# </script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__bFOh74rblCNfeAqBWGqF603OXHEBWOI8xUWm9gk-Mnw__EBNOtXb-FCEjFlZFDdnpg4YYSmssKyrojBPzZ8hk0lo__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var show_catfish=0; if (document.cookie.indexOf("catfishDisplayed=") == -1 || (dfp_preview_ids!= undefined && dfp_preview_ids.length!=0) ) { if(screen.width<=740) { googletag.cmd.push(function() {
# googletag.slots["catfish"] = googletag.defineSlot("/5908/bt/catfish/homepage", [1, 1], "dfp-ad-catfish")
#   .addService(googletag.pubads())
#   .setTargeting("pos", "catfish")
#   .setTargeting("weight", "3");});
# expiry = new Date();expiry.setTime(expiry.getTime() + (catfish_validity*60*60*1000));
#                 document.cookie = "catfishDisplayed=yes;path=/; expires=" + expiry.toGMTString(); show_catfish=1;}}
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
#
#         var show_overlay=0;
#         if ( topOverlayImpressionsServed < topOverlayImpressions && document.cookie.indexOf("topoverlayDisplayed=") == -1 || (dfp_preview_ids!= undefined && dfp_preview_ids.length!=0 ) ) {
#           if ( screen.width > 740) { googletag.cmd.push(function() {
# googletag.slots["prestitial"] = googletag.defineSlot("/5908/bt/prestitial/homepage", [1, 1], "dfp-ad-prestitial")
#   .addService(googletag.pubads())
#   .setTargeting("pos", "prestitial")
#   .setTargeting("weight", "3");});
# expiry = new Date();
#             expiry.setTime(expiry.getTime() + (overlay_validity*60*60*1000));
#             topOverlayImpressionsServed++;
#
#             if ( topOverlayImpressionsServed == topOverlayImpressions) {
#               document.cookie = "topoverlayDisplayed=yes;path=/; expires=" + expiry.toGMTString();
#               document.cookie = "topOverlayImpressionsServed=0;path=/; expires=" + expiry.toGMTString();
#             }
#             else {
#               document.cookie = "topOverlayImpressionsServed="+topOverlayImpressionsServed+";path=/; expires=" + expiry.toGMTString();
#             }
#
#             show_overlay=1;
#           }
#         }
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# googletag.cmd.push(function() {
# googletag.slots["imu1"] = googletag.defineSlot("/5908/bt/imu1/homepage", ['fluid', [300, 250]], "dfp-ad-imu1")
#   .addService(googletag.pubads())
#   .setTargeting("pos", "1")
#   .setTargeting("weight", "5");});
#
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# googletag.cmd.push(function() {
# googletag.slots["imu2"] = googletag.defineSlot("/5908/bt/imu2/homepage", [300, 250], "dfp-ad-imu2")
#   .addService(googletag.pubads())
#   .setTargeting("pos", "2")
#   .setTargeting("weight", "6");});
#
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# googletag.cmd.push(function() {
# googletag.slots["bi1"] = googletag.defineSlot("/5908/bt/bi1/homepage", 'fluid', "dfp-ad-bi1")
#   .addService(googletag.pubads())
#   .setTargeting("pos", "bi1")
#   .setTargeting("weight", "9");});
#
# //--><!]]>
# </script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__1cVcAlAmGW-_WqZTo-wfq-8mtXpfzungta3DqDicTAI__vdgPGMRwwyrUXQfltdvoguEr-B_FtWyUy5CJelGUV2g__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# googletag.cmd.push(function() {
#   googletag.pubads().enableAsyncRendering();
#   googletag.pubads().enableSingleRequest();
#   googletag.pubads().collapseEmptyDivs();
#   googletag.pubads().setTargeting("page", "home");
#  /** START BETTER AD CHANGES */
# googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#     if(googletag.slots["prestitial"] == event.slot || googletag.slots["asean_prestitial"] == event.slot ) {
#                 console.log("Better Ad -  slotRenderEnded Event");
#                 console.log("slotRenderEnded event.isEmpty - " + event.isEmpty);
#       if (event.isEmpty){   console.log("event.isEmpty " + event.isEmpty);
#         document.getElementById("MyPageOverlay").className = "";
#         reloadScrollBars();
#       } else {    console.log("Kill the prestitial_timer");
#         //Kill the prestitial_timer
#         window.clearTimeout(prestitial_timer);
#       }
#     }
#   });
#  googletag.pubads().setTargeting("referrer", tarref);
#  /** END BETTER AD CHANGES */
#
# function getMetatagContent(name) {
#    var metas = document.getElementsByTagName('meta');
#
#    for (var i=0; i<metas.length; i++) {
#       if (metas[i].getAttribute("name") == name ) {
#          return metas[i].getAttribute("content");
#       }
#    }
#     return "";
# }
# var articleid = getMetatagContent( "article_id" );
# var articletags = getMetatagContent( "article_tags" );
# if( articleid && window.location.href.indexOf("asean-business") > -1) {
#   googletag.pubads().setTargeting( "articleid", "ab_" + articleid );
#   googletag.pubads().setTargeting( "tag", articletags );
# }
#
# if (articleid ) {
#   googletag.pubads().setTargeting("page", "article");
# }
# googletag.enableServices();});
#
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# document.createElement( "picture" );
# //--><!]]>
# </script>
# <script type="text/javascript" src="/sites/all/themes/custom/businesstimes/js/ads_checker.js?qs7qoq"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var ad_blocker = 0; if(typeof ads_enabled == "undefined"){ ad_blocker = 1 }; var data4 = {"adblocker": ad_blocker};
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var data3 = {mc: "", np: ""};
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
#   (function ($) {
#       jQuery.ajax({
#         type: 'POST',
#         url: '/ldap/details.php',
#         dataType: 'json',
#         cache: true,
#         async: false,
#         beforeSend: function (){},
#         success: function (data) {
#           ac = data.service_type; visitorcat = data.service_type;
#           at = data.ldapw;
#           if(at == "undefined" || typeof at === "undefined") {
#             at = "";
#             visitorcat = 1;
#           }
#
#           // DMP
#           var meta = document.createElement('meta');
#           meta.id = 'ldapw';
#           meta.name = 'ldapw';
#           meta.content = data.ldapw ? data.ldapw : '';
#           document.getElementsByTagName('head')[0].appendChild(meta);
#         },
#         error: function (){
#           ac = ""; visitorcat = 1; at = "";
#
#           // DMP
#           var meta = document.createElement('meta');
#           meta.id = 'ldapw';
#           meta.name = 'ldapw';
#           meta.content = '';
#           document.getElementsByTagName('head')[0].appendChild(meta);
#         }
#       });
#   })(jQuery);var data1 = {ac: ac, at: at, visitorcat: visitorcat};var data2 = {"title":"BT_Homepage","articleid":"","chapter1":"","chapter2":"","level2":1,"ac":"","contenttype":"","contenttype_ga":"","pagination":"1","author":"","contentcat":1,"keyword":"","homepage":true,"dfp":{"section":"homepage","adunit":{"topspecial":null,"bottomspecial":null}},"data-widget-id-sb":"SB_1"};var _data = jQuery.extend( true, data1, data2, data3, data4);
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var localStoragePid = window.localStorage.getItem("_cc_id") || "";
# //--><!]]>
# </script>
# <script type="text/javascript" src="/sites/all/libraries/lightslider/js/lightslider.min.js?v2&amp;qs7qoq"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__7hSuu6-kDtEYEO7-mFzAY77G2QNnZa8JfvRD73nKeDQ__gl5__SIN9djF99zH4SQJpkecuI_y2SFNsxVzsbIoW0g__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__xa7LTLLtFOBIEAn6Vn26A2vfU1YX2CeorR8j7WN1OOo__lHotpy9jos2hyLu4BkjtICkSHufbJAGw9a9jiaJO0SM__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript" src="//adtag.sphdigital.com/tag/bt/js/bt_tags.js"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__UoWoCc1KvtRw0Mpcz2ok_V4wS8APz_GwqJSFDwMPCy4__2EwzWplOsCxHng0YECtKgmLASWpRIPPpUG8fvqzeYCg__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__dRl6vqvScXJoejuWpLw48kThu-LmfdiqS3T9GdBKNNU__JA4osvxmw5BfgPIogp5UfXIvACX11CsPx-pHcocaosk__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__Zszhjqa_i9yb_T62RUco4w-rBnzBPJDBPRb5HjXVVGE__DaIBK6DnU0DFV7zRJk7RkQ5diguDIhAh7WrzwxMgFrc__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# <!-- Facebook Pixel Code -->
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '1714621078759983');
# fbq('track', "PageView");
# <!-- End Facebook Pixel Code -->
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var scriptTag = document.createElement('SCRIPT');
# scriptTag.src = '//cdn.optimizely.com/js/8478633212.js';
# document.head.appendChild(scriptTag);
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"businesstimes","theme_token":"P4sNo5Up6fu5ehUjR4HiKChunkv4dxTy3YIziI04wE8","jquery_version":"1.10","css":{"modules\/system\/system.base.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.tabs.css":1,"misc\/ui\/jquery.ui.accordion.css":1,"sites\/all\/libraries\/chosen\/chosen.css":1,"sites\/all\/modules\/contrib\/chosen\/css\/chosen-drupal.css":1,"sites\/all\/libraries\/magnific-popup\/dist\/magnific-popup.css":1,"sites\/all\/modules\/contrib\/magnific_popup\/css\/mfp-formatter.css":1,"sites\/all\/modules\/contrib\/cache_consistent\/css\/cache_consistent.css":1,"sites\/all\/modules\/contrib\/calendar\/css\/calendar_multiday.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"sites\/all\/modules\/contrib\/date\/date_repeat_field\/date_repeat_field.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/iib\/css\/iib.css":1,"sites\/all\/modules\/contrib\/scald\/modules\/fields\/mee\/css\/editor-global.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/contrib\/panopoly_theme\/css\/panopoly-featured.css":1,"sites\/all\/modules\/contrib\/panopoly_theme\/css\/panopoly-accordian.css":1,"sites\/all\/modules\/contrib\/picture\/picture_wysiwyg.css":1,"sites\/all\/modules\/custom\/sph_sgx_block\/css\/sph_sgx_block.css":1,"sites\/all\/modules\/custom\/sph_ubs\/.\/css\/sph_ubs.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/back_to_top\/css\/back_to_top.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/libraries\/bootstrap\/css\/bootstrap.min.css":1,"sites\/all\/libraries\/bootstrap\/css\/bootstrap-theme.min.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/formtips\/formtips.css":1,"sites\/all\/modules\/contrib\/linkedin\/linkedin_status\/linkedin_status.css":1,"sites\/all\/modules\/contrib\/oembed\/oembed.base.css":1,"sites\/all\/modules\/contrib\/oembed\/oembed.theme.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/modules\/contrib\/rate\/rate.css":1,"sites\/all\/modules\/contrib\/classy_panel_styles\/cps_example\/styles\/css\/classy_panel_styles.css":1,"sites\/all\/modules\/contrib\/panels\/plugins\/layouts\/flexible\/flexible.css":1,"public:\/\/ctools\/css\/109ec395e6e3085d215a94ff7537ae71.css":1,"sites\/all\/modules\/custom\/widgets\/widgets.css":1,"sites\/all\/themes\/custom\/businesstimes\/layouts\/defaultlayout\/defaultlayout.css":1,"\/sites\/all\/libraries\/lightslider\/css\/lightslider.css?v2":1,"sites\/all\/themes\/custom\/businesstimes\/css\/style.css":1},"js":{"sites\/all\/modules\/contrib\/picture\/picturefill2\/picturefill.js":1,"sites\/all\/modules\/contrib\/picture\/picture.js":1,"sites\/all\/libraries\/livraison\/lib\/others.min.js":1,"sites\/all\/libraries\/livraison\/lib\/main.min.js":1,"sites\/all\/themes\/contrib\/bootstrap\/js\/bootstrap.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.effect.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.tabs.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.accordion.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"sites ...
# //--><!]]>
# </script>
#
#   <!-- Begin Lotame ID -->
#   <link rel="preconnect" href="https://tags.crwdcntrl.net" />
#   <link rel="preconnect" href="https://bcp.crwdcntrl.net" />
#   <link rel="dns-prefetch" href="https://tags.crwdcntrl.net" />
#   <link rel="dns-prefetch" href="https://bcp.crwdcntrl.net" />
#
#   <script>
#   try {
#     var storedAuds = window.localStorage.getItem("lotame_4342_auds") || "";
#     if (storedAuds) {
#       googletag.cmd.push(function() {
#         window.googletag.pubads().setTargeting("audid", storedAuds.split(","));
#       });
#     }
#
#     var localStoragePid = window.localStorage.getItem("_cc_id") || "";
#     if (localStoragePid) {
#       googletag.cmd.push(function() {
#         window.googletag.pubads().setTargeting("dfp_cc_id", localStoragePid);
#       });
#     }
#   } catch (e) {
#     console.log(e);
#   }
#
#   // Callback when targeting audience is ready to push latest audience data
#   var audienceReadyCallback = function(profile) {
#     // Get audiences as an array
#     var lotameAudiences = profile.getAudiences() || [];
#
#     // Set the new target audiences for call to Google
#     googletag.cmd.push(function() {
#       window.googletag.pubads().setTargeting("audid", lotameAudiences);
#     });
#
#     var lotamePid = profile.getProfileId() || "";
#     if (lotamePid) {
#       googletag.cmd.push(function() {
#         window.googletag.pubads().setTargeting("dfp_cc_id", lotamePid);
#       });
#     }
#   };
#
#   var data = null;
#   if (_data.at) {
#     data = {
#       behaviors: {
#         int: ["A1ldap"]
#       },
#       ruleBuilder: {
#         bt_ldapType: [_data.visitorcat.toString()]
#       },
#       thirdParty: {
#         namespace: "SPHN",
#         value: _data.at // ldap hashed id
#       }
#     }
#   }
#
#   // Lotame config
#   var lotameClientId = "4342";
#   var lotameTagInput = {
#     data: data,
#     config: {
#       clientId: Number(lotameClientId),
#       // audiences will write to localStorage under the key lotame_4342_auds
#       audienceLocalStorage: true,
#       onProfileReady: audienceReadyCallback
#     }
#   };
#
#   // Lotame initialization
#   var lotameConfig = lotameTagInput.config || {};
#   var namespace = window["lotame_" + lotameConfig.clientId] = {};
#   namespace.config = lotameConfig;
#   namespace.data = lotameTagInput.data || {};
#   namespace.cmd = namespace.cmd || [];
#   </script>
#
#   <script async src="https://tags.crwdcntrl.net/lt/c/4342/lt.min.js"></script>
#   <!-- End Lotame ID -->
#
#   <!--Visual Revenue Reader Response Tracking Script (v6) -->
#
#   <!--Smart App Banner implementation -->
#   <script type="text/javascript">
#   if (/(iPad).*AppleWebKit.*Mobile.*Safari/.test(navigator.userAgent)) {
#     var headNode = document.getElementsByTagName("head")[0];
#     var sbNode = document.createElement('meta');
#     sbNode.name = 'apple-itunes-app';
#     sbNode.content = 'app-id=531283825';
#     headNode.appendChild(sbNode);
#   } else if (/(iPhone|iPod).*AppleWebKit.*Mobile.*Safari/.test(navigator.userAgent)) {
#     var headNode = document.getElementsByTagName("head")[0];
#     var sbNode = document.createElement('meta');
#     sbNode.name = 'apple-itunes-app';
#     sbNode.content = 'app-id=531275824';
#     headNode.appendChild(sbNode);
#   }
#   </script>
#
#   <script src="/sites/all/themes/custom/businesstimes/js/ads_checker.js"></script>
#   <!--End -->
#
#   <!--Web Push Notification-->
#     <link rel="manifest" href="/manifest.json" />
#   <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async=""></script>
#   <script>
#   var OneSignal = window.OneSignal || [];
#   OneSignal.push(function() {
#     OneSignal.init({
#       appId: "fb44e344-8dc0-48e7-8bf5-63be6a351f6b",
#     });
#   });
#   </script>
#   <!-- End Web Push Notification-->
#
#   <!--Start - Remove subscribe and google play -->
#     <!--End - Remove subscribe and google play -->
#
#
#
#   <!--Better ad implementation-->
#   <script type="text/javascript">
#   var postitial_redirecturl;
#   var prestitial_timer;
#
#   function reloadScrollBars() {
#     document.documentElement.style.overflowY = 'auto'; // firefox, chrome
#     if (navigator.appVersion.indexOf("MSIE") != -1) {
#       document.body.scroll = "yes";
#     } // ie only
#   }
#
#   function unloadScrollBars() {
#     prestitial_timer = window.setTimeout(continueToSite, 15000);
#
#     document.documentElement.style.overflowY = 'hidden'; // firefox, chrome
#     if (navigator.appVersion.indexOf("MSIE") != -1) {
#       document.body.scroll = "no";
#     } // ie only
#   }
#
#   function continueToSite() {
#     document.getElementById("MyPageOverlay").className = "";
#     reloadScrollBars();
#   }
#
#   function kill_postitial() {
#     window.location.href = postitial_redirecturl;
#   }
#
#   window.addEventListener('message', closetopoverlay, false);
#
#   function closetopoverlay(evt) {
#
#     if (evt.data == 'close' || evt.data == 'bz-interstitial-close') {
#       console.log("close event called");
#       if (postitial_redirecturl) {
#         window.location.href = postitial_redirecturl;
#       } else {
#         document.getElementById("MyPageOverlay").className = "";
#         document.getElementById("dfp-ad-prestitial").style.height = 0;
#         reloadScrollBars();
#       }
#     }
#   }
#
#   function getParameterByName(name, url) {
#     if (!url) url = window.location.href;
#     name = name.replace(/[\[\]]/g, '\\$&');
#     var regex = new RegExp('[?&]' + name + '(=([^&#]*)|&|#|$)'),
#       results = regex.exec(url);
#     if (!results) return null;
#     if (!results[2]) return '';
#     return decodeURIComponent(results[2].replace(/\+/g, ' '));
#   }
#
#   var postitial_redirecturl;
#
#   function bindPostitial() {
#     console.log("bindPostitial");
#     //googletag.destroySlots([googletag.slots["topoverlay"]])
#     document.addEventListener('click', function(event) {
#       console.log("click event called");
#       var anchor = event.target.closest("a"); // Find closest Anchor (or self)
#       var currentdomain = window.location.href.split('/')[2];
#
#       if (anchor !== null) {
#         var anchorHref = anchor.getAttribute('href');
#         anchorHref = anchorHref.replace(/(<([^>]+)>)/gi, "");
#
#         if (!getParameterByName("page", anchorHref) && !getParameterByName("itok", anchorHref)) {
#           console.log(anchorHref);
#           if (anchorHref.indexOf(currentdomain) !== -1 || anchorHref.charAt(0) == "/" || anchorHref.match(
#               /http(s)*\:\/\/traffic.outbrain.com\//) != null) {
#             event.preventDefault(); // Don't navigate!
#             postitial_redirecturl = anchorHref;
#             console.log(postitial_redirecturl);
#             var dfpadunits = JSON.parse(loaded_dfp_tags);
#             var dynamic_postitial = dfpadunits['lb1']['adunit'];
#             if (typeof dynamic_postitial !== "undefined") {
#               console.log("dynamic_postitial");
#               dynamic_postitial = dynamic_postitial.replace("/lb1/", "/postitial/");
#
#
#               if (topOverlayImpressionsServed < topOverlayImpressions && document.cookie.indexOf(
#                   "postitialDisplayed=") == -1 || (dfp_preview_ids != undefined && dfp_preview_ids.length != 0)) {
#                 document.getElementById("MyPageOverlay").className = "overlayWhite";
#                 googletag.cmd.push(function() {
#                   var slot_topoverlay = googletag.defineSlot(dynamic_postitial, [1, 1], 'postitial_holder')
#                     .addService(googletag.pubads()).setTargeting("pos", "postitial");
#
#                   if (document.body.classList.contains('node-type-article') == true) {
#                     slot_topoverlay.setTargeting("bttags", googletag["slots"].lb1.getTargeting("bttags"));
#                     slot_topoverlay.setTargeting("btarticleid", googletag["slots"].lb1.getTargeting(
#                       "btarticleid"));
#                     slot_topoverlay.setTargeting("gs_channels", googletag["slots"].lb1.getTargeting(
#                       "gs_channels "));
#                   }
#
#                   googletag.pubads().addEventListener('slotRenderEnded', function(eventtopoverlay) {
#                     if (slot_topoverlay == eventtopoverlay.slot) {
#                       if (eventtopoverlay.isEmpty) {
#                         console.log("empty postitial");
#                         window.location.href = postitial_redirecturl;
#                       } else {
#                         var expiry = new Date();
#                         expiry.setTime(expiry.getTime() + (postitial_validity * 60 * 60 * 1000));
#                         topOverlayImpressionsServed++;
#
#                         if (topOverlayImpressionsServed == topOverlayImpressions) {
#                           document.cookie = "postitialDisplayed=yes;path=/; expires=" + expiry
#                             .toGMTString();
#                           document.cookie = "topOverlayImpressionsServed=0;path=/; expires=" + expiry
#                             .toGMTString();
#                         } else {
#                           document.cookie = "topOverlayImpressionsServed=" + topOverlayImpressionsServed +
#                             ";path=/; expires=" + expiry.toGMTString();
#                         }
#
#                         window.clearTimeout(postitial_timer);
#                       }
#                     }
#                   });
#                   googletag.cmd.push(function() {
#                     googletag.display('postitial_holder');
#                     googletag.pubads().refresh([slot_topoverlay], {
#                       changeCorrelator: false
#                     });
#                   });
#                 });
#               } else {
#                 console.log("Postitial frequency cap from cookie");
#                 window.location.href = postitial_redirecturl;
#               }
#               var postitial_timer = window.setTimeout(kill_postitial, 15000);
#             }
#           } else {
#             event.returnValue = true;
#           }
#         }
#       }
#
#     }, true);
#   }
#
#   if (window.ads_enabled !== undefined && screen.width <= 740) {
#     bindPostitial();
#   }
#   </script>
#   <style>
#   .overlayWhite {
#     height: 100%;
#     width: 100%;
#     position: fixed;
#     z-index: 10000001;
#     top: 0;
#     left: 0;
#     background-color: rgb(255, 255, 255);
#     background-color: rgba(255, 255, 255, 1);
#     overflow-y: hidden;
#   }
#   </style>
#   <!--Better ad implementation End-->
#
#   <!-- MYSPH login popup
#   <script type="text/javascript">var myObj;</script>-->
# </head>
#
# <body class="html front not-logged-in no-sidebars page-home beta home2 role-anonymous-user" >
#
#   <!--Better ad implementation Start-->
#   <div id="MyPageOverlay"></div>
#   <div id="postitial_holder" style="padding:1px;"></div>
#
#   <script>
#   if (window.ads_enabled !== undefined && (show_overlay == 1 || (dfp_preview_ids != undefined && dfp_preview_ids
#       .length != 0)) && screen.width > 740) {
#     document.getElementById("MyPageOverlay").className = "overlayWhite";
#     unloadScrollBars();
#   }
#   </script>
#   <!--Better ad implementation End-->
#
#   <!-- Google Tag Manager (noscript) -->
#   <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WH9XNQW" height="0" width="0"
#       style="display:none;visibility:hidden"></iframe></noscript>
#   <!-- End Google Tag Manager (noscript) -->
#     <div id="dfp-ad-prestitial-wrapper" class="dfp-tag-wrapper">
#     <div id="dfp-ad-prestitial" class="dfp-tag-wrapper">
#       <script type="text/javascript">
#       if (window.ads_enabled !== undefined && (show_overlay == 1 || (dfp_preview_ids != undefined && dfp_preview_ids
#           .length != 0)) && screen.width > 740) {
#         googletag.cmd.push(function() {
#           googletag.display("dfp-ad-prestitial");
#         });
#       }
#       </script>
#     </div>
#   </div>
#     <!-- mySPH++ alert Start-->
#   <div class="hidden mysph-unverified alert">
#     <a class="close" data-dismiss="alert" href="#">×</a>
#     <p><i class="text-red fa fa-bell"></i> Hello, your email is unverified. Please confirm <b
#         class="unverifiedemail"></b> for access to all your SPH accounts. <a
#         class="mysph_verify_email mysph-resend mysph-ga-verify" event-label="Top Banner" href="javascript:;">RESEND
#         VERIFICATION EMAIL</a></p>
#   </div>
#   <!-- mySPH++ alert End-->
#
#   <div id="skip-link">
#     <a href="#main-content" class="element-invisible element-focusable">Skip to main content</a>
#   </div>
#
#
# <header id="navbar" role="banner" class="master-header">
#   <div class="container relative">
#
#     <div class="top-first hidden-xs hidden-sm">
#       <div class="society">
#         <div class="google-translate">
#           <style type="text/css">
#           .goog-te-gadget,
#           .goog-te-menu-frame {
#             font-family: inherit !important;
#           }
#
#           .goog-te-gadget-simple {
#             padding: 10px;
#             border: 0;
#             background-color: transparent;
#           }
#           </style>
#           <div id="google_translate_element"></div>
#           <script type="text/javascript">
#           function googleTranslateElementInit() {
#             new google.translate.TranslateElement({
#               pageLanguage: 'en',
#               includedLanguages: 'en,id,jv,ms,ta,tl,hi,zh-CN,zh-TW',
#               gaTrack: true,
#               gaId: 'UA-21603044-1'
#             }, 'google_translate_element');
#           }
#           </script>
#           <script type="text/javascript"
#             src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit"></script>
#         </div>
#       </div>
#       <time class="header-date">Wed, Apr 28, 2021</time>
#       <div class="login-info-desktop text-center "></div>
#     </div>
#
#     <div class="top-next visible-md visible-lg
# ">
#
#             <h1><a class="site-title" href="/" title="Home"><img
#             src="/sites/all/themes/custom/businesstimes/images/vectors/bt-icon-black.svg" width="607px" /></a></h1>
#           </div>
#
#   </div>
#
#   <div class="new-nav-bar fixed-nav-bar ">
#
#     <div>
#             <h2 class="visible-xs visible-sm mobile-header"></h2>
#
#       <div class="top-menu container">
#         <a href="#" class="hamburger-btn btn btn-primary">
#           <span class="icon-bar"></span>
#           <span class="icon-bar"></span>
#           <span class="icon-bar"></span>
#         </a>
#         <form class="search-form">
#           <div class="search-wrap">
#             <a class="search-close fa fa-times fa-lg hidden"></a>
#             <a class="search-btn fa fa-search fa-lg"></a>
#           </div>
#         </form>
#         <label id="queryly_search_label" for="queryly_toggle" style="display: none; margin-bottom: 0px;">
#           <img class="queryly_search_button"
#             style="vertical-align:middle;width: 31px;cursor: pointer;padding: 5px;position: absolute;right: 70px;top: 10px;"
#             src="https://www.queryly.com/images/whitesearchicon.png">
#         </label>
#         <a href="/" class="hidden-md hidden-lg bt-logo hidden-md hidden-lg">
#                     <img src="/sites/all/themes/custom/businesstimes/images/vectors/bt-mobile-icon-white.svg" height="25" width="37" />
#                   </a>
#         <ul class="list-inline visible-md-flex visible-lg-flex">
#           <li><span id="item1" class="menu-links nolink">ALL NEWS</span></li><li class='hidden-xs hidden-sm'><span id="item2" class="menu-links nolink">WEEKLY</span></li><li><a href="/breaking-news">BREAKING</a></li><li><a href="/todays-paper">TODAY&#039;S PAPER</a></li><li><a href="/lifestyle">LIFESTYLE</a></li><li><a href="/opinion">OPINION</a></li><li><a href="/garage">GARAGE</a></li><li class='hidden-md'><a href="/sme">SME</a></li><li><a href="/asean-business">ASEAN</a></li><li class='hidden-md'><a href="/wealth">WEALTH</a></li><li><a href="/hub">HUB</a></li><li><a href="/notices-announcements" class="hidden">NOTICES</a></li><li class='right menu hidden-md' style='margin-left: auto;'><ul class='list-inline'><li><a href="/podcasts" title="Podcasts" class="fa fa-podcast text-normal fa-lg"></a></li><li><a href="/infographics" title="INFOGRAPHICS" class="fa fa-pie-chart text-normal fa-lg"></a></li><li><a href="/videos" title="VIDEOS" class="fa fa-video-camera text-normal fa-lg"></a></li><li><a href="http://epaper.businesstimes.com.sg" title="E-PAPER" class="fa fa-file-pdf-o text-normal fa-lg" target="_blank"></a></li></ul></li>        </ul>
#       </div>
#
#       <div id="searchbox" style="display:none;">
#         <div class="search-wrapper">
#           <form role="search">
#             <div class="input-group add-on">
#               <input class="form-control" placeholder="Search..." name="search-term" id="search-term" type="text"
#                 required>
#               <div class="input-group-btn">
#                 <button class="btn btn-default" type="submit"><i class="glyphicon glyphicon-search"></i></button>
#               </div>
#             </div>
#           </form>
#         </div>
#       </div>
#
#       <div id="menu" class="hidden">
#
#         <div class="container">
#           <div class="list-group row" id="MainMenu">
#
#             <div class="panel panel-main-1 col-md-8">
#
# ...
# <p class="text-center">&copy; 2021 SINGAPORE PRESS HOLDINGS LTD. REGN NO. 198402668E</p>
# </div>
#
#
# <!-- START Queryly -->
# <script src="https://www.queryly.com/js/queryly.v4.js"></script>
# <script src="https://www.queryly.com/js/businesstimes-advanced-search.js"></script>
# <script>
# queryly.init('ddcbe85e6bce42f7', document.querySelectorAll('header,footer,.container'));
# console.log('Visitorcat: ' + window._data.visitorcat);
# //setTimeout(function() {
# console.log("Body classes: " + jQuery('body').attr('class'));
# var whitelisted_users = ['xchen@queryly.com', 'joashyeo@sph.com.sg', 'cmartin@sph.com.sg', 'hannahk@sph.com.sg', 'dhaya@sph.com.sg', 'chuaws@sph.com.sg', 'muthusel@sph.com.sg', 'anuruby@sph.com.sg', 'zahid@sph.com.sg', 'karllin@sph.com.sg', 'sobanak@sph.com.sg'];
# //  if((window._data.visitorcat == 2 && !(jQuery('body').hasClass('mysph-loggedin'))) || jQuery.inArray(jQuery('#sph_user_name').text(), whitelisted_users) >= 0) {
#     console.log('inside');
#     jQuery('#queryly_search_label').css('display', 'block');
#     jQuery('.search-form').css('display', 'none');
# //  }
# //  console.log('after 3 sec');
# //}, 3000);
#
# // GA events for Queryly
# setTimeout(function() {
# jQuery(document).ready(function() {
#   var queryly_attr = jQuery('body').attr('data-queryly_hideimage');
#   if (typeof queryly_attr !== 'undefined' && queryly_attr == "true") {
#     // -- Search images are hidden.
#     jQuery('.queryly_search_button').click(function() {
#       console.log('Queryly w/o Image: Search icon clicked');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with no-image',
#         'eventAction': 'visible',
#         'eventLabel': '',
#         'nonInteraction': true
#       });
#     });
#     jQuery(document).on('click', '.queryly_item_innercontainer a.resultlink', function() {
#       console.log('Queryly w/o Image: Search result clicked');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with no-image',
#         'eventAction': 'click',
#         'eventLabel': jQuery(this).attr('href'),
#         'nonInteraction': false
#       });
#     });
#     if (jQuery('body').hasClass('page-search') && jQuery('#queryly_advanced_container').length > 0) {
#       console.log('Queryly w/o Image: Advanced Search page viewed');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with no-image',
#         'eventAction': 'visible',
#         'eventLabel': '',
#         'nonInteraction': true
#       });
#     }
#     jQuery(document).on('click', '#queryly_advanced_container .queryly_item_row a', function() {
#       console.log('Queryly w/o Image: Advanced Search result clicked');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with no-image',
#         'eventAction': 'click',
#         'eventLabel': jQuery(this).attr('href'),
#         'nonInteraction': false
#       });
#     });
#   } else {
#     // -- Search images are visible
#     jQuery('.queryly_search_button').click(function() {
#       console.log('Queryly with Image: Search icon clicked');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with image',
#         'eventAction': 'visible',
#         'eventLabel': '',
#         'nonInteraction': true, //true -> non interactive event (no impact on bounce rate), false -> interactive event (lower bounce rate)
#       });
#     });
#     jQuery(document).on('click', '.queryly_item_innercontainer a.resultlink', function() {
#       console.log('Queryly with Image: Search result clicked');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event',
#         'eventCategory': 'search result with image',
#         'eventAction': 'click',
#         'eventLabel': jQuery(this).attr('href'),
#         'nonInteraction': false
#       });
#     });
#     if (jQuery('body').hasClass('page-search') && jQuery('#queryly_advanced_container').length > 0) {
#       console.log('Queryly with Image: Advanced Search page viewed');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with image',
#         'eventAction': 'visible',
#         'eventLabel': '',
#         'nonInteraction': true
#       });
#     }
#     jQuery(document).on('click', '#queryly_advanced_container .queryly_item_row a', function() {
#       console.log('Queryly with Image: Advanced Search result clicked');
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'event': 'custom_event', //DO NOT CHANGE
#         'eventCategory': 'search result with image',
#         'eventAction': 'click',
#         'eventLabel': jQuery(this).attr('href'),
#         'nonInteraction': false
#       });
#     })
#   }
# });
# console.log('after 3 sec, waiting for GA to load the AB test');
# }, 3000);
# </script>
# <style>
# body[data-queryly_hideimage="true"] .queryly_item_imagecontainer, body[data-queryly_hideimage="true"] .queryly_advanced_item_imagecontainer {
#   display: none;
# }
# #queryly_advanced_container .filterbar{
#     margin-top: 0px !important;
# }
# </style>
# <!-- END Queryly -->
# </section>
# <section id="block-block-123" class="block block-block msa-survey alert alert-dismissable hidden clearfix">
#
#
#   <div class="container">
# <button aria-label="Close" class="close" data-dismiss="alert" type="button"><span class="fa fa-close"></span></button>
# <img src="https://www.businesstimes.com.sg/sites/all/themes/custom/businesstimes/images/vectors/bt-mobile-icon-white.svg" width="74/" class="hidden-xs" />
#
# <div class="text">
# <p><strong>Tell us what kind of news matters to you!</strong></p>
#
# <p>Participate in our reader survey now.</p>
# </div>
#
# <p><a class="link" href="https://sph.au1.qualtrics.com/jfe/form/SV_bOxitz2gufq8W4l" target="_blank" onclick="createCookie('msa-survey-click', 1)">TAKE READER SURVEY</a></p>
# </div>
# </section>
# <section id="block-block-124" class="block block-block clearfix">
#
#
#   <script>
# function createCookie(name, value, days) {
# 	if (days) {
# 		var date = new Date();
# 		date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
# 		var expires = "; expires=" + date.toGMTString();
# 	}
# 	else var expires = "";
# 		document.cookie = name + "=" + value + expires + "; path=/";
# 	}
# </script>
# </section>
#   </div>
# </footer>  <script type="text/javascript" src="/sites/default/files/advagg_js/js__nqIzhTzHqngWOCzYpMEF6J8fV2kzBRNr4ydYpI8BycU__otT7O46U_CSOIezDKQNPsM2mFOP5q0PdOtdhG3Zodd0__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js" async="async"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__8xV1KOTFkO0ViDTgEgwpgsMqhfW1LmiEoxiGA-a066w__ng6sa6Xkc2XhxjQHsaVb2iNYNu1V514dEua7Xb0oIcI__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
# <script type="text/javascript" src="/sites/default/files/advagg_js/js__ChUT0Cpt3ch0T35nhZgMgH5BzBQ5oyaFF27cnXxe7aU__S79mhsO6q7fWONLNt9XSEZx-JmiQeAEtuPkuVxIEjpY__dd3S9GTwy0OpssQ1-F6lsXCXAJlSzYV6yiUY9wVVTeE.js"></script>
#
#   <!-- Firebase push notification start -->
#     <!-- The core Firebase JS SDK is always required and must be listed first -->
#   <script src="https://www.gstatic.com/firebasejs/7.17.1/firebase-app.js"></script>
#   <script src="https://www.gstatic.com/firebasejs/7.17.1/firebase-messaging.js"></script>
#   <script>
#   var firebaseConfig = {
#     apiKey: "AIzaSyBlX0CRCx8qbywu1KyBpfUxV1C4JInrPJY",
#     authDomain: "bt-web-prod.firebaseapp.com",
#     databaseURL: "https://bt-web-prod.firebaseio.com",
#     projectId: "bt-web-prod",
#     storageBucket: "bt-web-prod.appspot.com",
#     messagingSenderId: "222590119815",
#     appId: "1:222590119815:web:ede237a6b77e43fc97ed22",
#   };
#
#   firebase.initializeApp(firebaseConfig);
#
#   const messaging = firebase.messaging();
#   messaging.usePublicVapidKey("BOq-3QvfLRM2oEmb1q4cV99AnJ3xZJKdU9xBdqfXB6uYuKKxIcMWBnodjQzP_t2tbd5jSH7wxtrtirCdBGW_S44");
#
#   messaging.onTokenRefresh(() => {
#     messaging.getToken().then((refreshedToken) => {
#       console.log('Token refreshed.');
#       // Indicate that the new Instance ID token has not yet been sent to the app server.
#       setTokenSentToServer(false);
#       // Send Instance ID token to app server.
#       sendTokenToServer(refreshedToken);
#       // [START_EXCLUDE]
#       // Display new Instance ID token and clear UI of all previous messages.
#       //resetUI();
#       // [END_EXCLUDE]
#     }).catch((err) => {
#       console.log('Unable to retrieve refreshed token ', err);
#     });
#   });
#
#   // messaging.onMessage((payload) => {
#   /* console.log('Message received. ', payload);
#
#   const notificationTitle = payload.notification.title;
#   const notificationOptions = {
#     body: payload.notification.body,
#     icon: payload.notification.icon,
#     data: {
#       click_action: payload.notification.click_action
#     }
#   };
#
#   console.log(payload.notification.click_action);
#
#   return self.registration.showNotification(notificationTitle, notificationOptions); */
#   // });
#
#   // Request permission and get token....
#   function permissions() {
#     messaging.requestPermission().then(function() {
#         console.log('Notification permission granted.');
#         return messaging.getToken();
#       })
#       .then(function(token) {
#         console.log('Device token: ' + token);
#
#         //subscribe to topic
#         subscribeTokenToTopic(token, 'bt-webpush');
#       })
#       .catch(function(err) {
#         console.log('Unable to get permission to notify.', err);
#       });
#   }
#
#   //Subscribe to topic
#   function subscribeTokenToTopic(token, topic) {
#     fetch('https://iid.googleapis.com/iid/v1/' + token + '/rel/topics/' + topic, {
#       method: 'POST',
#       headers: new Headers({
#         'Authorization': 'key=AAAAM9Nnr4c:APA91bFPPaS3ZewObngZpiFXzLAo6cRXWmuyv7XsjSP3eUdP7cMzXI3DIem21ERI0BcloSnKWBtzo8q9NQu7r4Rx1i7KKaacviFTceurnznhXMUtJEySa7ytnXYaZ3XZE14ChMIDLuxS'
#       })
#     }).then(response => {
#       if (response.status < 200 || response.status >= 400) {
#         throw 'Error subscribing to topic: ' + response.status + ' - ' + response.text();
#       }
#       console.log('Subscribed to "' + topic + '"');
#       jQuery('.firebase-bell-container').hide();
#     }).catch(error => {
#       console.error(error);
#     })
#   }
#
#   function unSubscribeTokenToTopic(token, topic) {
#     fetch('https://iid.googleapis.com/iid/v1/' + token + '/rel/topics/' + topic, {
#       method: 'DELETE',
#       headers: new Headers({
#         'Authorization': 'key=AAAAM9Nnr4c:APA91bFPPaS3ZewObngZpiFXzLAo6cRXWmuyv7XsjSP3eUdP7cMzXI3DIem21ERI0BcloSnKWBtzo8q9NQu7r4Rx1i7KKaacviFTceurnznhXMUtJEySa7ytnXYaZ3XZE14ChMIDLuxS'
#       })
#     }).then(response => {
#       if (response.status < 200 || response.status >= 400) {
#         throw 'Error subscribing to topic: ' + response.status + ' - ' + response.text();
#       }
#       console.log('UnSubscribed to "' + topic + '"');
#     }).catch(error => {
#       console.error(error);
#     })
#   }
#
#   function sendTokenToServer(currentToken) {
#     if (!isTokenSentToServer()) {
#       console.log('Sending token to server...');
#       // TODO(developer): Send the current token to your server.
#       setTokenSentToServer(true);
#     } else {
#       console.log('Token already sent to server so won\'t send it again ' +
#         'unless it changes');
#     }
#
#   }
#
#   function isTokenSentToServer() {
#     return window.localStorage.getItem('sentToServer') === '1';
#   }
#
#   function setTokenSentToServer(sent) {
#     window.localStorage.setItem('sentToServer', sent ? '1' : '0');
#   }
#
#   permissions();
#   </script>
#
#   <div class='firebase-bell-container' style="display: none;">
#     <span class='firebase-bell-launcher'>
#       <a href='javascript:;' class='firebase-bell-icon' onclick="javascript:permissions();" data-toggle="tooltip"
#         data-placement="left" title="Subscribe to BT latest news notifications">
#         <img src='/sites/all/themes/custom/businesstimes/images/notification.png' />
#       </a>
#     </span>
#   </div>
#   <!-- End Firebase push notification -->
#
#   <img src="//amplifypixel.outbrain.com/pixel?mid=00529a8e9e01c3bfad3c4bd7ec1ab148f6" width="1" height="1" />
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"5d870fc25a","applicationID":"439190759","transactionName":"ZVVVbUcDW0JZWxYIV1wfdlpBC1pfF0gDBl1tXVZXVAVQQ2dIAwZdbVVPXFYXQVQ=","queueTime":0,"applicationTime":4422,"atts":"SRJWGw8ZSEw=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
#
#
# <!-- START ldap sso-->
# <script type="text/javascript">
# function trySingleSignOnLogin() {
#   var f = document.createElement('iframe');
#   f.src = "/ldap/login.php";
#   f.style.width = "0px";
#   f.style.height = "0px";
#   f.style.border = "none";
#   jQuery('body').append(f);
# }
#
# function loadSubscriberContent() {
#   jQuery.post("/ldap/login_details?article_id=" + _data.articleid, function(data) {
#     //data = JSON.parse(data);
#     var current_url = window.location.pathname;
#     var loginid = data.loginid.replace(/(<([^>]+)>)/gi, "");
#     if ( /^[a-zA-Z0-9_\.]*$/.test(loginid) ) {
#       // var login_info = '<ul>'+
#       // '<li class="header-home-group subscribe-link">Hi <a class="mysph_user_name" href="#" id="sph_user_name" >'+loginid+'</a></li>'+
#       // '<li class="header-home-group login-link"><a class="mysph_logout" href="#">Log out</a></li></ul>';
#       // // Append login info
#       // jQuery(".login-info").html(login_info);
#
#       var unverified_bell = '';
#       var unverified_menu = '';
#       if (data.usertype == 'y-reg' && data.userstatus != 'verified') {
#         unverified_bell = '<i class="fa fa-bell text-red"></i> ';
#         unverified_menu =
#           '<li><a href="javascript:;" class="mysph_verify_email text-red mysph-ga-verify" event-label="Dropdown Login Menu">Please verify your email</a></li>';
#
#         jQuery("#paywall-resent-email").removeClass('hidden');
#         jQuery(".cxense_wall").hide();
#
#         // Show the unverified email banner on top of the site
#         jQuery(".mysph-unverified").removeClass("hidden");
#         jQuery(".mysph-unverified .unverifiedemail").html(loginid);
#       }
#
#       login_info = '<div class="dropdown">' + unverified_bell +
#         'HI <a href="javascript:;" class="dropdown-toggle login_user_name"  data-toggle="dropdown"><span id="sph_user_name">' +
#         loginid +
#         '</span><i class="caret-icon fa fa-caret-down un"></i></a><ul class="dropdown-menu"><i class="fa fa-caret-up dw"></i>' +
#         unverified_menu +
#         '<li><a class="mysph_user_name"  href="javascript:;">Update your password</a></li><li><a class="mysph_logout" href="javascript:;">Logout</a></li></ul></div>';
#       login_info_mobile = unverified_bell +
#         'HI <a class="login_user_name" data-toggle="collapse" href="#collapseLogin" aria-expanded="false" aria-controls="collapseLogin"><span id="sph_user_name">' +
#         loginid +
#         '</span><i class="caret-icon fa fa-caret-down un"></i></a><div class="collapse" id="collapseLogin"><ul>' +
#         unverified_menu +
#         '<li style="padding-bottom: 15px; border-right: 0px;"><a class="mysph_user_name"  href="javascript:;">Update your password</a></li><li><a class="mysph_logout" href="javascript:;">Logout</a></li></ul></div>';
#
#
#       jQuery(".login-info-desktop").html(login_info);
#       jQuery(".mobile-login .login-info").html(login_info_mobile);
#
#
#       // Update full content
#       if (data.paid && data.full_content != "") {
#         //jQuery(".field-name-body").html(data.full_content);
#         jQuery(".field-name-body #block-block-82").remove();
#         jQuery(".field-name-body .body-copy").replaceWith(data.full_content);
#       }
#     }
#   });
# }
# </script>
# <!-- END ldap sso -->
#
#
#
#
# </html>
